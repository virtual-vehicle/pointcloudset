# %%
import lidar
import rosbag
from pathlib import Path
from dask.distributed import Client
from dask import delayed
import dask.dataframe as dd
import dask

client = Client()  # start distributed scheduler locally.  Launch dashboard
# %load_ext autoreload
# %autoreload 2
# %config IPCompleter.greedy=True
# Out:
# Failed to load Python extension for LZ4 support. LZ4 compression will not be available.

# %%
bagfile = "/workspaces/lidar/tests/testdata/big.bag"

# %%
test0= lidar.Dataset.from_file(Path(bagfile), start_frame_number = 0, end_frame_number = 25)
# Out:
# 100%|██████████| 25/25 [00:07<00:00,  3.38it/s]

# %%
test1= lidar.Dataset.from_file(Path(bagfile), start_frame_number = 0, end_frame_number = 25)
# Out:
# ...
# 100%|██████████| 8/8 [00:02<00:00,  3.27it/s]

# %%
len(test0)
# Out:
# 25

# %%
test0.timestamps == test1.timestamps
# Out:
# True

# %%
# %%time
testall= lidar.Dataset.from_file(Path(bagfile))
# Out:
# ...
#  30%|██▉       | 29/97 [02:49<09:58,  8.80s/it]distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
#  33%|███▎      | 32/97 [03:14<10:57, 10.11s/it]distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# ...
#  48%|████▊     | 47/97 [05:21<13:05, 15.70s/it]distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
#  52%|█████▏    | 50/97 [05:38<06:35,  8.42s/it]

# %%
ds = test0
res = [(i,(ds.timestamps[i+1] - ds.timestamps[i ]).microseconds / 1000000) for i in range(len(ds.timestamps) - 1)]

# %%
test = res[0][1]

# %%
len(testall)
# Out:
# 0.099094

# %%
res
# Out:
# [(0, 0.099094),
#  (1, 0.124292),
#  (2, 0.093222),
#  (3, 0.08267),
#  (4, 0.123615),
#  (5, 0.069339),
#  (6, 0.122351),
#  (7, 0.07661),
#  (8, 0.11829),
#  (9, 0.090337),
#  (10, 0.10737),
#  (11, 0.093234),
#  (12, 0.088417),
#  (13, 0.106996),
#  (14, 0.108604),
#  (15, 0.098331),
#  (16, 0.098638),
#  (17, 0.111103),
#  (18, 0.0847),
#  (19, 0.112604),
#  (20, 0.08783),
#  (21, 0.10016),
#  (22, 0.109661),
#  (23, 0.090647),
#  (24, 0.112903),
#  (25, 0.099035),
#  (26, 0.113254),
#  (27, 0.073879),
#  (28, 0.099973),
#  (29, 0.09722),
#  (30, 0.13095),
#  (31, 0.072176),
#  (32, 0.105232),
#  (33, 0.088762),
#  (34, 0.212072),
#  (35, 0.020276),
#  (36, 0.080207),
#  (37, 0.090571),
#  (38, 0.109691),
#  (39, 0.097209),
#  (40, 0.104309),
#  (41, 0.097238),
#  (42, 0.102378),
#  (43, 0.090964),
#  (44, 0.09662),
#  (45, 0.095372),
#  (46, 0.105186),
#  (47, 0.091677),
#  (48, 0.107284),
#  (49, 0.093962),
#  (50, 0.100144),
#  (51, 0.124788),
#  (52, 0.078213),
# ...
